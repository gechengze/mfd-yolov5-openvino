# %% [markdown]
# ## 1.mfd_yolov5s6三种模型对比

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5s6.pt --source demo.mp4 --project test --name pt --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5s6.pt'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=pt, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Fusing layers...
# Model summary: 280 layers, 12315904 parameters, 0 gradients, 16.2 GFLOPs
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.055s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.049s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.051s)
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5s6.onnx --source demo.mp4 --project test --name onnx --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5s6.onnx'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=onnx, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5s6.onnx for ONNX Runtime inference...
# requirements: onnxruntime not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openvino 2022.1.0 requires numpy<1.20,>=1.16.6, but you have numpy 1.22.4 which is incompatible.
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5s6_openvino_model/ --source demo.mp4 --project test --name openvino --exist-ok --data input/mfd.yaml
# Out:
# detect: weights=['models/mfd_yolov5s6_openvino_model/'], source=demo.mp4, data=input/mfd.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=openvino, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5s6_openvino_model for OpenVINO inference...
# requirements: openvino not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnxruntime 1.11.1 requires numpy>=1.21.0, but you have numpy 1.19.5 which is incompatible.
# ...

# %% [markdown]
# ## 2.mfd_yolov5m6三种模型对比

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5m6.pt --source demo.mp4 --project test --name pt --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5m6.pt'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=pt, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Fusing layers...
# Model summary: 378 layers, 35260464 parameters, 0 gradients, 49.0 GFLOPs
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.122s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.116s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.118s)
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5m6.onnx --source demo.mp4 --project test --name onnx --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5m6.onnx'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=onnx, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5m6.onnx for ONNX Runtime inference...
# requirements: onnxruntime not found and is required by YOLOv5, attempting auto-update...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/numpy/
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5m6_openvino_model/ --source demo.mp4 --project test --name openvino --exist-ok --data input/mfd.yaml
# Out:
# detect: weights=['models/mfd_yolov5m6_openvino_model/'], source=demo.mp4, data=input/mfd.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=openvino, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5m6_openvino_model for OpenVINO inference...
# requirements: openvino not found and is required by YOLOv5, attempting auto-update...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/numpy/
# ...

# %% [markdown]
# ## 3.mfd_yolov5l6三种模型对比

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5l6.pt --source demo.mp4 --project test --name pt --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5l6.pt'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=pt, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Fusing layers...
# Model summary: 476 layers, 76134048 parameters, 0 gradients, 110.1 GFLOPs
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.233s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.230s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.231s)
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5l6.onnx --source demo.mp4 --project test --name onnx --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5l6.onnx'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=onnx, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5l6.onnx for ONNX Runtime inference...
# requirements: onnxruntime not found and is required by YOLOv5, attempting auto-update...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/numpy/
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5l6_openvino_model/ --source demo.mp4 --project test --name openvino --exist-ok --data input/mfd.yaml
# Out:
# detect: weights=['models/mfd_yolov5l6_openvino_model/'], source=demo.mp4, data=input/mfd.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=openvino, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5l6_openvino_model for OpenVINO inference...
# requirements: openvino not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnxruntime 1.11.1 requires numpy>=1.21.0, but you have numpy 1.19.5 which is incompatible.
# ...

# %% [markdown]
# ## 4.mfd_yolov5x6三种模型对比

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5x6.pt --source demo.mp4 --project test --name pt --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5x6.pt'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=pt, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Fusing layers...
# Model summary: 574 layers, 139990096 parameters, 0 gradients, 208.1 GFLOPs
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.411s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.407s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.410s)
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5x6.onnx --source demo.mp4 --project test --name onnx --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5x6.onnx'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=onnx, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5x6.onnx for ONNX Runtime inference...
# requirements: onnxruntime not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openvino 2022.1.0 requires numpy<1.20,>=1.16.6, but you have numpy 1.22.4 which is incompatible.
# ...

# %%
# !python yolov5/detect.py --device cpu --weights models/mfd_yolov5x6_openvino_model/ --source demo.mp4 --project test --name openvino --exist-ok --data input/mfd.yaml
# Out:
# detect: weights=['models/mfd_yolov5x6_openvino_model/'], source=demo.mp4, data=input/mfd.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=openvino, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5x6_openvino_model for OpenVINO inference...
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 640x640 1 with_mask, Done. (0.315s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 640x640 1 with_mask, Done. (0.307s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 640x640 1 with_mask, Done. (0.306s)
# ...

# %% [markdown]
# ## 5.pytorch-gpu对比

# %%
# !python yolov5/detect.py --device 0 --weights models/mfd_yolov5s6.pt --source demo.mp4 --project test --name pt --exist-ok
# !python yolov5/detect.py --device 0 --weights models/mfd_yolov5m6.pt --source demo.mp4 --project test --name pt --exist-ok
# !python yolov5/detect.py --device 0 --weights models/mfd_yolov5l6.pt --source demo.mp4 --project test --name pt --exist-ok
# !python yolov5/detect.py --device 0 --weights models/mfd_yolov5x6.pt --source demo.mp4 --project test --name pt --exist-ok
# Out:
# detect: weights=['models/mfd_yolov5x6.pt'], source=demo.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=test, name=pt, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CUDA:0 (NVIDIA GeForce RTX 3080, 10018MiB)
#
# Fusing layers...
# Model summary: 574 layers, 139990096 parameters, 0 gradients, 208.1 GFLOPs
# video 1/1 (1/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.019s)
# video 1/1 (2/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.019s)
# video 1/1 (3/322) /home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/demo.mp4: 576x640 1 with_mask, Done. (0.019s)
# ...

# %% [markdown]
# ## 6.推理精度对比（以yolov5s6为例）

# %%
# !python yolov5/val.py --device cpu --weights models/mfd_yolov5s6.pt --data input/mfd.yaml --img 640
# Out:
# val: data=input/mfd.yaml, weights=['models/mfd_yolov5s6.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=cpu, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Fusing layers...
# Model summary: 280 layers, 12315904 parameters, 0 gradients, 16.2 GFLOPs
# val: Scanning '/home/gechengze/deep-learning/fdu/mfd-yolov5-openvino/input/val.c
#                Class     Images     Labels          P          R     mAP@.5 mAP@libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
#                Class     Images     Labels          P          R     mAP@.5 mAP@libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# ...

# %%
# !python yolov5/val.py --device cpu --weights models/mfd_yolov5s6.onnx --data input/mfd.yaml --img 640
# Out:
# val: data=input/mfd.yaml, weights=['models/mfd_yolov5s6.onnx'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=cpu, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5s6.onnx for ONNX Runtime inference...
# requirements: onnxruntime not found and is required by YOLOv5, attempting auto-update...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/numpy/
# ...

# %%
# !python yolov5/val.py --device cpu --weights models/mfd_yolov5s6_openvino_model/ --data input/mfd.yaml --img 640
# Out:
# val: data=input/mfd.yaml, weights=['models/mfd_yolov5s6_openvino_model/'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=cpu, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.8.13 torch-1.10.1 CPU
#
# Loading models/mfd_yolov5s6_openvino_model for OpenVINO inference...
# requirements: openvino not found and is required by YOLOv5, attempting auto-update...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/numpy/
# ...
